# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
oldlink='https://ycyang.web.cern.ch/ycyang/cgi-bin/igprof-navigator/CMSSW_8_1_0_pre2_igprofCPU'
newlink='https://ycyang.web.cern.ch/ycyang/cgi-bin/igprof-navigator/CMSSW_8_1_0_pre3_igprofCPU'


new_req=requests.get(newlink)
new_html = new_req.text
new_soup = BeautifulSoup(new_html,'html.parser')

old_req=requests.get(oldlink)
old_html = old_req.text
old_soup = BeautifulSoup(old_html,'html.parser')

# %%
### new parsing
## make data frame
columns=new_soup.select('tr > th')
columnlist=[]
for column in columns:
    columnlist.append(column.text)
print(columnlist)
new_df=pd.DataFrame(columns=columnlist)

contents = new_soup.select('tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.find_all("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
new_df=pd.DataFrame(columns=columnlist, data=alldfcontents)
# Out:
# ['Rank', 'Total % ', 'Cumulative ', 'Symbol name']

# %%
### old parsing
## make data frame
columns=old_soup.select('tr > th')
columnlist=[]
for column in columns:
    columnlist.append(column.text)
print(columnlist)
old_df=pd.DataFrame(columns=columnlist)

contents = old_soup.select('tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.find_all("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
old_df=pd.DataFrame(columns=columnlist, data=alldfcontents)
# Out:
# ['Rank', 'Total % ', 'Cumulative ', 'Symbol name']

# %%
print(new_df.dtypes)
print(old_df.dtypes)
display(new_df)
# Out:
# 1    13,536.43
# Name: Cumulative , dtype: object
# Rank           object
# Total %        object
# Cumulative     object
# Symbol name    object
# dtype: object
# Rank           object
# Total %        object
# Cumulative     object
# Symbol name    object
# dtype: object
#       Rank Total %  Cumulative   \
# 0     None     None        None
# 1        1   100.00   13,521.19
# 2        2    99.96   13,515.90
# 3        3    99.96   13,515.88
# 4        4    99.96   13,515.24
# 5        5    99.95   13,514.77
# 6        6    99.00   13,386.16
# 7       10    98.46   13,313.23
# 8        9    98.46   13,313.23
# 9        8    98.46   13,313.23
# 10       7    98.46   13,313.23
# 11      13    98.46   13,313.19
# 12      12    98.46   13,313.19
# 13      11    98.46   13,313.19
# 14      14    98.45   13,311.04
# 15      15    97.76   13,218.21
# 16      16    97.75   13,217.35
# 17      17    97.75   13,217.34
# 18      18    97.75   13,217.21
# 19      19    97.75   13,216.97
# 20      20    97.75   13,216.90
# 21      21    97.75   13,216.56
# 22      22    93.56   12,650.40
# 23      23    84.28   11,395.64
# 24      24    84.28   11,395.15
# 25      25    25.42    3,436.45
# 26      26    25.28    3,417.91
# 27      27    25.27    3,416.98
# 28      28    25.27    3,416.82
# 29      29    25.27    3,416.81
# ...    ...      ...         ...
# 971    971     0.16       21.73
# 972    972     0.16       21.72
# 973    973     0.16       21.70
# 974    974     0.16       21.69
# 975    975     0.16       21.63
# 976    976     0.16       21.61
# 977    977     0.16       21.57
# 978    978     0.16       21.54
# 979    979     0.16       21.54
# 980    980     0.16       21.49
# 981    981     0.16       21.48
# 982    982     0.16       21.39
# 983    983     0.16       21.31
# 984    984     0.16       21.30
# 985    985     0.16       21.27
# 986    986     0.16       21.25
# 987    987     0.16       21.23
# 988    988     0.16       21.22
# 989    989     0.16       21.17
# 990    990     0.16       21.14
# 991    991     0.16       21.13
# 992    992     0.16       21.06
# 993    993     0.16       21.06
# 994    994     0.16       21.05
# 995    995     0.16       21.03
# 996    996     0.16       20.97
# 997    997     0.15       20.92
# 998    998     0.15       20.87
# 999    999     0.15       20.84
# 1000  1000     0.15       20.83
#
#                                             Symbol name
# 0                                                  None
# 1                                         <spontaneous>
# 2                                     __libc_start_main
# 3                                                _start
# 4                                                  main
# 5                main::{lambda()#1}::operator()() const
# 6                edm::EventProcessor::runToCompletion()
# 7            edm::EventProcessor::readAndProcessEvent()
# 8      statemachine::HandleEvent::readAndProcessEvent()
# 9     statemachine::HandleEvent::HandleEvent(boost::...
# 10    boost::statechart::state<statemachine::HandleE...
# 11    edm::EventProcessor::processEventsForStreamAsy...
# 12                 edm::StreamProcessingTask::execute()
# 13    tbb::internal::custom_scheduler<tbb::internal:...
# 14      edm::EventProcessor::processEvent(unsigned int)
# 15    void edm::StreamSchedule::processOneEvent<edm:...
# 16    void edm::StreamSchedule::processOneEvent<edm:...
# 17    decltype ({parm#1}()) edm::convertException::w...
# 18    void edm::Path::processOneOccurrence<edm::Occu...
# 19    decltype ({parm#1}()) edm::convertException::w...
# 20    bool edm::Worker::doWork<edm::OccurrenceTraits...
# 21    decltype ({parm#1}()) edm::convertException::w...
# 22    boost::statechart::simple_state<statemachine::...
# 23    edm::WorkerT<edm::stream::EDProducerAdaptorBas...
# 24    edm::stream::EDProducerAdaptorBase::doEvent(ed...
# 25    edm::Principal::prefetch(unsigned int, bool, e...
# 26    edm::UnscheduledProductResolver::resolveProduc...
# 27    edm::UnscheduledProductResolver::resolveProduc...
# 28    bool edm::Worker::doWork<edm::OccurrenceTraits...
# 29    decltype ({parm#1}()) edm::convertException::w...
# ...                                                 ...
# 971                     TempTrajectory::pushAux(double)
# 972   PFDisplacedVertexCandidateFinder::associate(st...
# 973                               PyEval_EvalFrameEx'11
# 974   muonisolation::JetExtractor::deposit(edm::Even...
# 975   PFDisplacedVertexCandidateFinder::associate(st...
# 976   cling::Interpreter::DeclareInternal(std::basic...
# 977   PFDisplacedVertexCandidateFinder::associate(st...
# 978   pat::PATTauProducer::produce(edm::Event&, edm:...
# 979   pat::PATPackedCandidateProducer::produce(edm::...
# 980   PFDisplacedVertexCandidateFinder::associate(st...
# 981                                       __ieee754_exp
# 982   PFDisplacedVertexCandidateFinder::associate(st...
# 983   cling::IncrementalParser::ParseInternal(llvm::...
# 984   PFDisplacedVertexCandidateFinder::associate(st...
# 985          TGenCollectionStreamer::Streamer(TBuffer&)
# 986   SiStripRecHit2D::cloneSH(TkCloner const&, Traj...
# 987   ClosestApproachInRPhi::calculate(FreeTrajector...
# 988   char* std::basic_string<char, std::char_traits...
# 989   PFDisplacedVertexCandidateFinder::associate(st...
# 990                                       PyObject_Call
# 991   PFDisplacedVertexCandidateFinder::associate(st...
# 992   PFDisplacedVertexCandidateFinder::associate(st...
# 993   clang::Parser::ParseTopLevelDecl(clang::Opaque...
# 994   TkClonerImpl::makeShared(SiStripRecHit2D const...
# 995   edm::service::ELstatistics::log(edm::ErrorObj ...
# 996   Surface::side(Point3DBase<float, GlobalTag> co...
# 997   PFDisplacedVertexCandidateFinder::associate(st...
# 998   PFDisplacedVertexCandidateFinder::associate(st...
# 999   FreeTrajectoryState::createCurvilinearError(Ca...
# 1000  Eigen::internal::general_matrix_matrix_product...
#
# [1001 rows x 4 columns]

# %%
###  step1 
total=columnlist[1]

print("### legacy modules CMSSW_8_1_0_pre2 --> CMSSW_8_1_0_pre3")

strs=["edm::WorkerT<edm::EDProducer>::implDo(",
"edm::WorkerT<edm::stream::EDProducerAdaptorBase>::implDo(",
"edm::WorkerT<edm::one::OutputModuleBase>::implDo("]


for str in strs:
    
    idx_old=old_df.loc[old_df['Symbol name'].str.startswith(str,na=False)].index
    idx_new=new_df.loc[new_df['Symbol name'].str.startswith(str,na=False)].index

    if(idx_old.size !=0 and idx_new.size!=0):
        result_old=old_df.loc[idx_old[0]][total]
        result_new=new_df.loc[idx_new[0]][total]
        print("{0:<5} ====> {1:<10}   {2:>30}".format(old_df.loc[idx_old[0]][total],new_df.loc[idx_new[0]][total],str))
    elif(idx_old.size!=0 and idx_new.size==0):
        print("{0:<5} ====> {1:<10}   {2:>30}".format(old_df.loc[idx_old[0]][total],"None",str))
    elif(idx_old.size==0 and idx_new.size!=0):
        print("{0:<5} ====> {1:<10}   {2:>30}".format("None",new_df.loc[idx_new[0]][total],str))
    elif(idx_old.size==0 and idx_new.size==0):
        print("{0:<5} ====> {1:<10}   {2:>30}".format("None","None",str))
#display(old_df[old_df['Symbol name'].str.startswith('edm::WorkerT<edm::EDProducer>::implDo(',na=False)][total])
#display(new_df[new_df['Symbol name'].str.startswith('edm::WorkerT<edm::EDProducer>::implDo(',na=False)][total])
# Out:
# ### legacy modules CMSSW_8_1_0_pre2 --> CMSSW_8_1_0_pre3
# None  ====> None         edm::WorkerT<edm::EDProducer>::implDo(
# 84.29 ====> 84.28        edm::WorkerT<edm::stream::EDProducerAdaptorBase>::implDo(
# 5.86  ====> 5.92         edm::WorkerT<edm::one::OutputModuleBase>::implDo(

# %%
### step2

str2="edm::stream::EDProducerAdaptorBase::doEvent("

link_list=[]
for link in old_soup.findAll("a"):
    if 'href' in link.attrs:
        name=link.text
        if name.startswith(str2):
            link_list.append(link.attrs['href'])
            #print(link.attrs['href'])
            
old_str2_link="https://ycyang.web.cern.ch"+link_list[0]
print(old_str2_link)

link_list=[]
for link in new_soup.findAll("a"):
    if 'href' in link.attrs:
        name=link.text
        if name.startswith(str2):
            link_list.append(link.attrs['href'])
            #print(link.attrs['href'])
            
new_str2_link="https://ycyang.web.cern.ch"+link_list[0]
print(new_str2_link)
# Out:
# https://ycyang.web.cern.ch/ycyang/cgi-bin/igprof-navigator/CMSSW_8_1_0_pre2_igprofCPU/24
# https://ycyang.web.cern.ch/ycyang/cgi-bin/igprof-navigator/CMSSW_8_1_0_pre3_igprofCPU/24

# %%
old_req=requests.get(old_str2_link)
old_html = old_req.text
old_str2_soup = BeautifulSoup(old_html,'html.parser')

new_req=requests.get(new_str2_link)
new_html = new_req.text
new_str2_soup = BeautifulSoup(new_html,'html.parser')

# %%
columnlist=['Rank','total','count_to/from','count_total','path_including','path_total','name']

contents = old_str2_soup.select('tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.find_all("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]

old_str2_df=pd.DataFrame(columns=columnlist, data=alldfcontents)

contents = new_str2_soup.select('tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.find_all("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]

new_str2_df=pd.DataFrame(columns=columnlist, data=alldfcontents)

# %%
str2_list = list(old_str2_df[4:24]['name'])
print("### top 20 ::stream ED producers Rank and Cost [CMSSW_8_1_0_pre2 --> CMSSW_8_1_0_pre3]")

for str2 in str2_list:
    idx_new=new_str2_df.loc[new_str2_df['name']==str2].index 
    idx_old=old_str2_df.loc[old_str2_df['name']==str2].index  # 1 2 3 4 5... 20
    print("[{0:<2} -> {1:<2}] [{2:<2} -> {3:<2}] {4:>40}".format(idx_old[0]-3, idx_new[0]-3, old_str2_df.loc[idx_old[0]]['total'],new_str2_df.loc[idx_new[0]]['total'],str2))
# Out:
# ### top 20 ::stream ED producers Rank and Cost [CMSSW_8_1_0_pre2 --> CMSSW_8_1_0_pre3]
# [1  -> 1 ] [23.88 -> 23.83] cms::CkfTrackCandidateMakerBase::produceBase(edm::Event&, edm::EventSetup const&)
# [2  -> 2 ] [7.46 -> 7.53] SeedGeneratorFromRegionHitsEDProducer::produce(edm::Event&, edm::EventSetup const&)
# [3  -> 3 ] [7.40 -> 7.44] TrackProducer::produce(edm::Event&, edm::EventSetup const&)
# [4  -> 4 ] [6.33 -> 6.39] MuonIdProducer::produce(edm::Event&, edm::EventSetup const&)
# [5  -> 5 ] [5.54 -> 5.70] HcalHitReconstructor::produce(edm::Event&, edm::EventSetup const&)
# [6  -> 6 ] [3.30 -> 3.27] PFDisplacedVertexProducer::produce(edm::Event&, edm::EventSetup const&)
# [7  -> 7 ] [2.07 -> 2.05] PrimaryVertexProducer::produce(edm::Event&, edm::EventSetup const&)
# [8  -> 8 ] [1.56 -> 1.56] pat::PATElectronSlimmer::produce(edm::Event&, edm::EventSetup const&)
# [9  -> 9 ] [1.55 -> 1.54] FastjetJetProducer::produce(edm::Event&, edm::EventSetup const&)
# [10 -> 10] [1.18 -> 1.13] EcalUncalibRecHitProducer::produce(edm::Event&, edm::EventSetup const&)
# [11 -> 11] [1.05 -> 1.07] TopProjector<reco::PFCandidate, reco::PFCandidate, TopProjectorFwdPtrOverlap<reco::PFCandidate, reco::PFCandidate> >::produce(edm::Event&, edm::EventSetup const&)
# [12 -> 12] [1.00 -> 1.03] ConversionTrackCandidateProducer::produce(edm::Event&, edm::EventSetup const&)
# [13 -> 13] [0.98 -> 0.97] RecoTauProducer::produce(edm::Event&, edm::EventSetup const&)
# [14 -> 14] [0.93 -> 0.93] GsfTrackProducer::produce(edm::Event&, edm::EventSetup const&)
# [15 -> 15] [0.92 -> 0.92] RecoTauJetRegionProducer::produce(edm::Event&, edm::EventSetup const&)
# [16 -> 16] [0.88 -> 0.89] TrackMVAClassifierBase::produce(edm::Event&, edm::EventSetup const&)
# [17 -> 17] [0.83 -> 0.83] TauDiscriminationProducerBase<reco::PFTau, reco::PFTauDiscriminator>::produce(edm::Event&, edm::EventSetup const&)
# [18 -> 22] [0.82 -> 0.71] PFClusterProducer::produce(edm::Event&, edm::EventSetup const&)
# [19 -> 18] [0.81 -> 0.78] PFCand_AssoMap::produce(edm::Event&, edm::EventSetup const&)
# [20 -> 19] [0.78 -> 0.78] CosmicMuonProducer::produce(edm::Event&, edm::EventSetup const&)

# %%
str3=["EcalUncalibRecHitProducer::produce(edm::Event&, edm::EventSetup const&)",
"MultiTrackSelector::run(edm::Event&, edm::EventSetup const&) const",
"cms::CkfTrackCandidateMakerBase::produceBase(edm::Event&, edm::EventSetup const&)",
"SeedGeneratorFromRegionHitsEDProducer::produce(edm::Event&, edm::EventSetup const&)",
"MuonIdProducer::produce(edm::Event&, edm::EventSetup const&)",
"CosmicsMuonIdProducer::produce(edm::Event&, edm::EventSetup const&)",
"HcalHitReconstructor::produce(edm::Event&, edm::EventSetup const&)"]

Cumulative=old_df.columns[2]

oldAll=list(old_df.loc[old_df['Symbol name']=="<spontaneous>"][Cumulative])[0]
oldAll=float(oldAll.replace(',','').strip())

print("### Delta Check : [CMSSW_8_1_0_pre3 - CMSSW_8_1_0_pre2 / total * 100% = delta]")

for str in str3:
    
    idx_old=old_df.loc[old_df['Symbol name']==str].index
    idx_new=new_df.loc[new_df['Symbol name']==str].index
    
    if(idx_old.size ==0 or idx_new.size==0): continue;
    
    
    oldVal=float(old_df.loc[idx_old[0]][Cumulative].replace(',','').strip())
    newVal=float(new_df.loc[idx_new[0]][Comulative].replace(',','').strip())
    delta= round((newVal - oldVal) / oldAll * 100.0,2)
    
    print("{0:7}  - {1:7} / {2} *100% = {3:5}%  {4:<30}".format(newVal,oldVal,oldAll,delta,str))
# Out:
# ### Delta Check : [CMSSW_8_1_0_pre3 - CMSSW_8_1_0_pre2 / total * 100% = delta]
#  153.26  -  159.99 / 13536.43 *100% = -0.05%  EcalUncalibRecHitProducer::produce(edm::Event&, edm::EventSetup const&)
# 3221.88  - 3232.68 / 13536.43 *100% = -0.08%  cms::CkfTrackCandidateMakerBase::produceBase(edm::Event&, edm::EventSetup const&)
# 1017.69  - 1009.78 / 13536.43 *100% =  0.06%  SeedGeneratorFromRegionHitsEDProducer::produce(edm::Event&, edm::EventSetup const&)
#  863.77  -  857.43 / 13536.43 *100% =  0.05%  MuonIdProducer::produce(edm::Event&, edm::EventSetup const&)
#   770.3  -  749.88 / 13536.43 *100% =  0.15%  HcalHitReconstructor::produce(edm::Event&, edm::EventSetup const&)

# %%
# Out:
# 13536.43
